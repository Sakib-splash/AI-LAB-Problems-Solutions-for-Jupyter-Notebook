# %%
import pandas as pd


#code by sakib
data = { 
    'Area': [2000, 1800, 2500, 2200, 1900, 2800, 2100, 1700, 2400, 2000], 
    'Bedrooms': [3, 2, 4, 3, 2, 5, 4, 2, 3, 3], 
    'Bathrooms': [2, 1.5, 3, 2.5, 2, 3.5, 2.5, 1, 3, 2], 
    'Age': [10, 5, 15, 8, 3, 20, 12, 6, 18, 9], 
    'Location': ['Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Suburban'], 
    'Garage_Size': [400, 300, 500, 450, 350, 600, 400, 250, 550, 400], 
    'Yard_Size': [800, 600, 1000, 900, 700, 1200, 800, 500, 1100, 800], 
    'Amenities': [1, 0, 1, 1, 0, 1, 1, 0, 1, 1], 
    'School_Rating': [8, 7, 6, 9, 8, 5, 7, 6, 4, 8], 
    'Distance_to_City_Center': [5, 2, 10, 7, 4, 15, 6, 3, 12, 5], 
    'Price': [300000, 250000, 350000, 320000, 280000, 400000, 310000, 240000, 370000, 300000] 
}

df = pd.DataFrame(data)
print(df)

def print_house_details(index):
    print(f"House {index+1}:")
    print(f"  Area: {df.at[index, 'Area']} sq ft")
    print(f"  Bedrooms: {df.at[index, 'Bedrooms']}")
    print(f"  Bathrooms: {df.at[index, 'Bathrooms']}")
    print(f"  Age: {df.at[index, 'Age']} years")
    print(f"  Location: {df.at[index, 'Location']}")
    print(f"  Garage Size: {df.at[index, 'Garage_Size']} sq ft")
    print(f"  Yard Size: {df.at[index, 'Yard_Size']} sq ft")
    print(f"  Amenities: {'Yes' if df.at[index, 'Amenities'] == 1 else 'No'}")
    print(f"  School Rating: {df.at[index, 'School_Rating']} / 10")
    print(f"  Distance to City Center: {df.at[index, 'Distance_to_City_Center']} miles")
    print(f"  Price: ${df.at[index, 'Price']:,}\n")


for i in range(len(df)):
    print_house_details(i)
# Out:
#    Area  Bedrooms  Bathrooms  Age  Location  Garage_Size  Yard_Size  \
# 0  2000         3        2.0   10  Suburban          400        800
# 1  1800         2        1.5    5     Urban          300        600
# 2  2500         4        3.0   15     Rural          500       1000
# 3  2200         3        2.5    8  Suburban          450        900
# 4  1900         2        2.0    3     Urban          350        700
# 5  2800         5        3.5   20     Rural          600       1200
# 6  2100         4        2.5   12  Suburban          400        800
# 7  1700         2        1.0    6     Urban          250        500
# 8  2400         3        3.0   18     Rural          550       1100
# 9  2000         3        2.0    9  Suburban          400        800
#
#    Amenities  School_Rating  Distance_to_City_Center   Price
# 0          1              8                        5  300000
# 1          0              7                        2  250000
# 2          1              6                       10  350000
# 3          1              9                        7  320000
# 4          0              8                        4  280000
# 5          1              5                       15  400000
# 6          1              7                        6  310000
# 7          0              6                        3  240000
# 8          1              4                       12  370000
# 9          1              8                        5  300000
# House 1:
#   Area: 2000 sq ft
#   Bedrooms: 3
#   Bathrooms: 2.0
#   Age: 10 years
#   Location: Suburban
#   Garage Size: 400 sq ft
#   Yard Size: 800 sq ft
#   Amenities: Yes
#   School Rating: 8 / 10
#   Distance to City Center: 5 miles
#   Price: $300,000
#
# House 2:
#   Area: 1800 sq ft
#   Bedrooms: 2
#   Bathrooms: 1.5
#   Age: 5 years
#   Location: Urban
#   Garage Size: 300 sq ft
#   Yard Size: 600 sq ft
#   Amenities: No
#   School Rating: 7 / 10
#   Distance to City Center: 2 miles
#   Price: $250,000
#
# House 3:
#   Area: 2500 sq ft
#   Bedrooms: 4
#   Bathrooms: 3.0
#   Age: 15 years
#   Location: Rural
#   Garage Size: 500 sq ft
#   Yard Size: 1000 sq ft
#   Amenities: Yes
#   School Rating: 6 / 10
#   Distance to City Center: 10 miles
#   Price: $350,000
#
# House 4:
#   Area: 2200 sq ft
#   Bedrooms: 3
#   Bathrooms: 2.5
#   Age: 8 years
#   Location: Suburban
#   Garage Size: 450 sq ft
#   Yard Size: 900 sq ft
#   Amenities: Yes
#   School Rating: 9 / 10
#   Distance to City Center: 7 miles
#   Price: $320,000
#
# House 5:
#   Area: 1900 sq ft
#   Bedrooms: 2
#   Bathrooms: 2.0
#   Age: 3 years
#   Location: Urban
#   Garage Size: 350 sq ft
#   Yard Size: 700 sq ft
#   Amenities: No
#   School Rating: 8 / 10
#   Distance to City Center: 4 miles
#   Price: $280,000
#
# House 6:
#   Area: 2800 sq ft
#   Bedrooms: 5
#   Bathrooms: 3.5
#   Age: 20 years
#   Location: Rural
#   Garage Size: 600 sq ft
#   Yard Size: 1200 sq ft
#   Amenities: Yes
#   School Rating: 5 / 10
#   Distance to City Center: 15 miles
#   Price: $400,000
#
# House 7:
#   Area: 2100 sq ft
#   Bedrooms: 4
#   Bathrooms: 2.5
#   Age: 12 years
#   Location: Suburban
#   Garage Size: 400 sq ft
#   Yard Size: 800 sq ft
#   Amenities: Yes
#   School Rating: 7 / 10
#   Distance to City Center: 6 miles
#   Price: $310,000
#
# House 8:
#   Area: 1700 sq ft
#   Bedrooms: 2
#   Bathrooms: 1.0
#   Age: 6 years
#   Location: Urban
#   Garage Size: 250 sq ft
#   Yard Size: 500 sq ft
#   Amenities: No
#   School Rating: 6 / 10
#   Distance to City Center: 3 miles
#   Price: $240,000
#
# House 9:
#   Area: 2400 sq ft
#   Bedrooms: 3
#   Bathrooms: 3.0
#   Age: 18 years
#   Location: Rural
#   Garage Size: 550 sq ft
#   Yard Size: 1100 sq ft
#   Amenities: Yes
#   School Rating: 4 / 10
#   Distance to City Center: 12 miles
#   Price: $370,000
#
# House 10:
#   Area: 2000 sq ft
#   Bedrooms: 3
#   Bathrooms: 2.0
#   Age: 9 years
#   Location: Suburban
#   Garage Size: 400 sq ft
#   Yard Size: 800 sq ft
#   Amenities: Yes
#   School Rating: 8 / 10
#   Distance to City Center: 5 miles
#   Price: $300,000
